# %%
# %pip install llama-index-core
# %pip install llama-index-embeddings-zhipuai
# %pip install llama-index-llms-zhipuai
# %pip install llama-index-readers-file
# %pip install llama-index-vector-stores-faiss
# %pip install llamaindex-py-client
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama-index-core in f:\pycharm_project\wow-agent\.venv\lib\site-packages (0.12.10.post1)
# Requirement already satisfied: PyYAML>=6.0.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (3.11.11)
# Requirement already satisfied: dataclasses-json in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (2024.12.0)
# Requirement already satisfied: httpx in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (3.9.1)
# Requirement already satisfied: numpy in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (0.9.0)
# Requirement already satisfied: wrapt in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core) (1.18.3)
# Requirement already satisfied: click in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core) (8.1.8)
# Requirement already satisfied: joblib in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core) (3.1.1)
# Requirement already satisfied: colorama in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from dataclasses-json->llama-index-core) (3.25.1)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core) (4.8.0)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core) (24.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx->llama-index-core) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simpleNote: you may need to restart the kernel to use updated packages.
#
# Collecting llama-index-embeddings-zhipuai
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/6a/af/5b62fbc4256f00173b35e14bb406415f4202d2d323adda3991d9ba142ce2/llama_index_embeddings_zhipuai-0.2.0-py3-none-any.whl (2.9 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-embeddings-zhipuai) (0.12.10.post1)
# Collecting zhipuai<3.0.0.0,>=2.1.5.20230904 (from llama-index-embeddings-zhipuai)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/b2/02/b8e4241dd256cda075c026bc008205a000c4bc57a2ff82291ab0d38b86be/zhipuai-2.1.5.20250106-py3-none-any.whl (105 kB)
# Requirement already satisfied: PyYAML>=6.0.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.11.11)
# Requirement already satisfied: dataclasses-json in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2024.12.0)
# Requirement already satisfied: httpx in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.9.1)
# Requirement already satisfied: numpy in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.9.0)
# Requirement already satisfied: wrapt in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.17.2)
# Collecting cachetools>=4.2.2 (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-embeddings-zhipuai)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a4/07/14f8ad37f2d12a5ce41206c21820d8cb6561b728e51fad4530dff0552a67/cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: pydantic-core>=2.14.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-embeddings-zhipuai) (2.27.2)
# Collecting pyjwt<2.9.0,>=2.8.0 (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-embeddings-zhipuai)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/2b/4f/e04a8067c7c96c364cef7ef73906504e2f40d690811c021e1a1901473a19/PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.18.3)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (4.8.0)
# Requirement already satisfied: certifi in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.0.7)
# Requirement already satisfied: idna in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.14.0)
# Requirement already satisfied: click in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (8.1.8)
# Requirement already satisfied: joblib in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.1.1)
# Requirement already satisfied: colorama in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (3.25.1)
# Requirement already satisfied: packaging>=17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (24.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-zhipuai) (1.3.1)
# Installing collected packages: pyjwt, cachetools, zhipuai, llama-index-embeddings-zhipuai
# Successfully installed cachetools-5.5.0 llama-index-embeddings-zhipuai-0.2.0 pyjwt-2.8.0 zhipuai-2.1.5.20250106
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting llama-index-llms-zhipuai
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/39/27/887fbb4b05f72110f15332faaf77453eedca23a56684bff227ba4b9e62f5/llama_index_llms_zhipuai-0.2.1-py3-none-any.whl (5.5 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-llms-zhipuai) (0.12.10.post1)
# Requirement already satisfied: zhipuai<3.0.0.0,>=2.1.5.20230904 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-llms-zhipuai) (2.1.5.20250106)
# Requirement already satisfied: PyYAML>=6.0.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.11.11)
# Requirement already satisfied: dataclasses-json in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2024.12.0)
# Requirement already satisfied: httpx in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.9.1)
# Requirement already satisfied: numpy in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.9.0)
# Requirement already satisfied: wrapt in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.17.2)
# Requirement already satisfied: cachetools>=4.2.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-llms-zhipuai) (5.5.0)
# Requirement already satisfied: pydantic-core>=2.14.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-llms-zhipuai) (2.27.2)
# Requirement already satisfied: pyjwt<2.9.0,>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from zhipuai<3.0.0.0,>=2.1.5.20230904->llama-index-llms-zhipuai) (2.8.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.18.3)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (4.8.0)
# Requirement already satisfied: certifi in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.0.7)
# Requirement already satisfied: idna in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.14.0)
# Requirement already satisfied: click in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (8.1.8)
# Requirement already satisfied: joblib in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.1.1)
# Requirement already satisfied: colorama in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (3.25.1)
# Requirement already satisfied: packaging>=17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (24.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-zhipuai) (1.3.1)
# Installing collected packages: llama-index-llms-zhipuai
# Successfully installed llama-index-llms-zhipuai-0.2.1
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: llama-index-readers-file in f:\pycharm_project\wow-agent\.venv\lib\site-packages (0.4.3)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-readers-file) (4.12.3)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-readers-file) (0.12.10.post1)
# Requirement already satisfied: pandas in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-readers-file) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-readers-file) (5.1.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-readers-file) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file) (2.6)
# Requirement already satisfied: PyYAML>=6.0.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.11.11)
# Requirement already satisfied: dataclasses-json in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.12.0)
# Requirement already satisfied: httpx in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.9.1)
# Requirement already satisfied: numpy in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.9.0)
# Requirement already satisfied: wrapt in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pandas->llama-index-readers-file) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pandas->llama-index-readers-file) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.18.3)
# Requirement already satisfied: click in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (8.1.8)
# Requirement already satisfied: joblib in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.27.2)
# Requirement already satisfied: six>=1.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.1.1)
# Requirement already satisfied: colorama in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (3.25.1)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (4.8.0)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (24.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-readers-file) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting llama-index-vector-stores-faiss
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/21/16/d3f512f47d40a27ee1c75ce86faa91004de9c20202ca376fe35bc92ba413/llama_index_vector_stores_faiss-0.3.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-vector-stores-faiss) (0.12.10.post1)
# Requirement already satisfied: PyYAML>=6.0.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.0.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.0.37)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.11.11)
# Requirement already satisfied: dataclasses-json in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.15)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.8)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.12.0)
# Requirement already satisfied: httpx in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.28.1)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.9.1)
# Requirement already satisfied: numpy in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.2.1)
# Requirement already satisfied: pillow>=9.0.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.10.5)
# Requirement already satisfied: requests>=2.31.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (9.0.0)
# Requirement already satisfied: tiktoken>=0.3.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.8.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.9.0)
# Requirement already satisfied: wrapt in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.18.3)
# Requirement already satisfied: click in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (8.1.8)
# Requirement already satisfied: joblib in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (2024.12.14)
# Requirement already satisfied: greenlet!=0.4.17 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.1.1)
# Requirement already satisfied: colorama in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from tqdm<5.0.0,>=4.66.1->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (3.25.1)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (4.8.0)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (0.14.0)
# Requirement already satisfied: packaging>=17.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (24.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-vector-stores-faiss) (1.3.1)
# Installing collected packages: llama-index-vector-stores-faiss
# Successfully installed llama-index-vector-stores-faiss-0.3.0
# Note: you may need to restart the kernel to use updated packages.
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting llamaindex-py-client
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/5e/9c/a1a3086f023a8957ebd527c98d9356b6dd9409edef827ffdeee484f47abf/llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
# Requirement already satisfied: httpx>=0.20.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llamaindex-py-client) (0.28.1)
# Requirement already satisfied: pydantic>=1.10 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from llamaindex-py-client) (2.10.5)
# Requirement already satisfied: anyio in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx>=0.20.0->llamaindex-py-client) (4.8.0)
# Requirement already satisfied: certifi in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx>=0.20.0->llamaindex-py-client) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx>=0.20.0->llamaindex-py-client) (1.0.7)
# Requirement already satisfied: idna in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpx>=0.20.0->llamaindex-py-client) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.20.0->llamaindex-py-client) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=1.10->llamaindex-py-client) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=1.10->llamaindex-py-client) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from pydantic>=1.10->llamaindex-py-client) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in f:\pycharm_project\wow-agent\.venv\lib\site-packages (from anyio->httpx>=0.20.0->llamaindex-py-client) (1.3.1)
# Installing collected packages: llamaindex-py-client
# Successfully installed llamaindex-py-client-0.1.19
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()
# 从环境变量中读取api_key
api_key = os.getenv('ZISHU_API_KEY')
base_url = "https://open.bigmodel.cn/api/paas/v4/"
chat_model = "glm-4-flash"
emb_model = "embedding-3"

# %% [markdown]
# # 配置模型思路一（使用Llama-index为智谱构建的专门的包）

# %% [markdown]
# ## 配置对话模型

# %%
from llama_index.llms.zhipuai import ZhipuAI
llm = ZhipuAI(
    api_key = api_key,
    model = chat_model,
)

# %% [markdown]
# # 测试对话模型、配置嵌入模型、测试嵌入模型

# %%
# 测试对话模型
response = llm.complete("你是谁？")
print(response)

# 配置嵌入模型
from llama_index.embeddings.zhipuai import ZhipuAIEmbedding
embedding = ZhipuAIEmbedding(
    api_key = api_key,
    model = emb_model,
)

# 测试嵌入模型
emb = embedding.get_text_embedding("你好呀呀")
len(emb), type(emb)
# Out:
# 我是一个人工智能助手，名叫 ChatGLM，是基于清华大学 KEG 实验室和智谱 AI 公司于 2024 年共同训练的语言模型开发的。我的任务是针对用户的问题和要求提供适当的答复和支持。
# (1024, list)
